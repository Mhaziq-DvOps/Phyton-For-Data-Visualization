# %%
name=input("what is your name")
# Out:
# what is your nameHaziq

# %%
print(name)
# Out:
# Haziq

# %%
age=(int(input("what is your age?")))
# Out:
# what is your age?10

# %%
print(age)
# Out:
# 30

# %%
if age>=30:
# Out:
#   Cell In[5], line 1
#     if age>=30:
#                ^
# SyntaxError: incomplete input

# %%
if age>=30:
    print(name,"is allowed to in")
elif age<30:
    print(name,"is not allowed in")
# Out:
# Haziq is not allowed in

# %%
import pandas as pd

# %%
df=pd.read_excel(r"\Users\User\Documents\Python Data Analysis Project (3 May 2025)\Taxis_Data.xlsx")
df
#df = data frame as excel worksheet
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# ...

# %%
#what are the payment types taxis have?
df.groupby("payment").count()
# Out:
#              pickup  dropoff  passengers  distance  fare   tip  tolls  total  \
# payment
# cash           1812     1812        1812      1812  1812  1812   1812   1812
# credit card    4577     4577        4577      4577  4577  4577   4577   4577
#
#              color  pickup_zone  dropoff_zone  pickup_borough  dropoff_borough
# payment
# cash          1812         1807          1796            1807             1796
# credit card   4577         4557          4549            4557             4549

# %%
#what's the average fare by number of passengers?
df.groupby("passengers")["fare"].mean()
# Out:
# passengers
# 0    12.734375
# 1    13.037061
# 2    13.167237
# 3    14.016461
# 4    13.040909
# 5    12.568592
# 6    14.042484
# Name: fare, dtype: float64

# %%
#whats the average fare by taxi color
df.groupby("color")["fare"].mean()
# Out:
# color
# green     14.040886
# yellow    12.919963
# Name: fare, dtype: float64

# %%
#whats are the 10 highest fares on this dataset?
df["fare"].max()
# Out:
# 150.0

# %%
df.nlargest(10,"fare")
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 5364 2019-03-17 16:59:17 2019-03-17 18:04:08           2     36.70  150.0
# 5648 2019-03-19 14:21:35 2019-03-19 15:51:28           2     33.46  150.0
# 4050 2019-03-13 14:05:19 2019-03-13 15:01:16           6     33.76  143.5
# 2231 2019-03-11 10:17:31 2019-03-11 11:03:55           1     26.35  130.0
# 622  2019-03-12 19:52:36 2019-03-12 19:52:55           3      0.00  120.0
# 3644 2019-03-19 23:30:50 2019-03-19 23:32:33           2      0.00  103.0
# 4815 2019-03-08 11:25:08 2019-03-08 11:50:30           3     10.36  100.0
# 4219 2019-03-08 20:07:54 2019-03-08 21:10:00           1     36.66   96.5
# 5567 2019-03-07 00:28:57 2019-03-07 02:02:55           1     25.51   93.5
# 3500 2019-03-11 17:18:03 2019-03-11 18:27:48           1     24.63   87.5
#
#         tip  tolls   total   color      payment           pickup_zone  \
# 5364   0.00  24.02  174.82  yellow         cash           JFK Airport
# ...

# %%
#but now we only wants to see filter to only sees the fare column only
df.nlargest(10,"fare")["fare"]
# Out:
# 5364    150.0
# 5648    150.0
# 4050    143.5
# 2231    130.0
# 622     120.0
# 3644    103.0
# 4815    100.0
# 4219     96.5
# 5567     93.5
# 3500     87.5
# Name: fare, dtype: float64

# %%
#for data visualization part, we need to have library such as matplotlib
# !pip install seaborn matplotlib

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#create a chart with the fare distribution
sns.histplot(df["fare"], bins=50)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
#is there a relationship between fares and distances?
#use scatter to show the relationship
#now we define the x and y axis to show more specific to the data, which is now between distance and fare
sns.scatterplot(x="distance",y="fare", data =df)
# Out:
# <Axes: xlabel='distance', ylabel='fare'>

# %%
#graph above shows ,as the distance go up, the fare also go up
#more visualization can be found in seaborn website, can copy and paste the chart style to implement in your project
